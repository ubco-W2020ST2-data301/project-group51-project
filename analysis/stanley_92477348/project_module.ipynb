# %% [markdown]
# ## EDA

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
from scripts import project_functions as pf # This is called a relative import
n = "/Users/a123/Desktop/School/UBC_2021Summer/Cosc301/Project/Cosc301_project_dataset.csv"

# %%
pf.load_and_process(n)
# Out:
#        age    occupation marriage status education level default  balance  \
# 0       58    management         married        tertiary      no     2143
# 1       44    technician          single       secondary      no       29
# 2       33  entrepreneur         married       secondary      no        2
# 3       47   blue-collar         married         unknown      no     1506
# 4       33       unknown          single         unknown      no        1
# ...    ...           ...             ...             ...     ...      ...
# 45206   51    technician         married        tertiary      no      825
# 45207   71       retired        divorced         primary      no     1729
# 45208   72       retired         married       secondary      no     5715
# 45209   57   blue-collar         married       secondary      no      668
# 45210   37  entrepreneur         married       secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
pf.cleanUp(n)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-2bc43831a1ab> in <module>
# ----> 1 pf.cleanUp(n)
#
# ~/Desktop/School/UBC_2021Summer/Cosc301/Project/Milestone2/analysis/scripts/project_functions.py in cleanUp(n)
#      15 def cleanUp(n):
#      16     df = (
# ---> 17           pd.read_csv(n, delimiter=';')
#      18         .drop(['default','default','contact','day','month','duration','campaign','pdays','previous','poutcome'],axis='columns')
#      19         .loc['balance'].fillna(0)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ...

# %%
pf.analysis1(n)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-1a3933d9d84a> in <module>
# ----> 1 pf.analysis1(n)
#
# ~/Desktop/School/UBC_2021Summer/Cosc301/Project/Milestone2/analysis/scripts/project_functions.py in analysis1(n)
#      36 def analysis1(n):
#      37     df = (
# ---> 38         pd.read_csv(n, delimiter=';')
#      39         .median() #we know
#      40         .groupby('have termed deposit')['age'].median()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1718         axis = self._get_axis_number(axis)
#    1719
# -> 1720         return SeriesGroupBy(
#    1721             obj=self,
#    1722             keys=by,
#
# ...

# %%
pf.analysis2(n)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-02fe4776ca75> in <module>
# ----> 1 pf.analysis2(n)
#
# ~/Desktop/School/UBC_2021Summer/Cosc301/Project/Milestone2/analysis/scripts/project_functions.py in analysis2(n)
#      51 def analysis2(n):
#      52     df = (
# ---> 53         pd.read_csv(n, delimiter=';')
#      54         .median() #we know
#      55         .groupby('have termed deposit')['balance'].median()
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1718         axis = self._get_axis_number(axis)
#    1719
# -> 1720         return SeriesGroupBy(
#    1721             obj=self,
#    1722             keys=by,
#
# ...

# %%
pf.visual(n)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-60d196f4e964> in <module>
# ----> 1 pf.visual(n)
#
# ~/Desktop/School/UBC_2021Summer/Cosc301/Project/Milestone2/analysis/scripts/project_functions.py in visual(n)
#      65 def visual(n):
#      66     df = (
# ---> 67           pd.read_csv(n, delimiter=';')
#      68         .sns.countplot(y='have termed deposit',data=df6)
#      69         .sns.countplot(y='age',data=df6)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sns'

# %%
name1 = "YK"
height_m1 = 2
weight_kg1 = 90

# %%
result1 = pf.bmi_calculator(name1, height_m1, weight_kg1)
# Out:
# bmi:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e971c3167c22> in <module>
# ----> 1 result1 = pf.bmi_calculator(name1, height_m1, weight_kg1)
#
# ~/Desktop/School/UBC_2021Summer/Cosc301/Project/Milestone2/analysis/scripts/project_functions.py in bmi_calculator(name, height_m, weight_kg)
#      76     bmw = weight_kg / (height_m ** 2)
#      77     print("bmi: ")
# ---> 78     print(bmi)
#      79     if bmi < 25:
#      80         return name + " not overweight"
#
# NameError: name 'bmi' is not defined
